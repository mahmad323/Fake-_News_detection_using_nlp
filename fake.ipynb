# %%
pip install pandas scikit-learn matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install nltk
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import re
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import pandas as pd

# %%
import nltk 
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\xpert\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
import pandas as pd
import csv

# Assuming the file path is correct
file_path ="fake_news.csv"

try:
    news_dataset = pd.read_csv(file_path, quoting=csv.QUOTE_NONE, on_bad_lines='skip', encoding="ISO-8859-1")
    print("Dataset loaded successfully!")
except FileNotFoundError:
    print(f"Error: File not found at {file_path}")
except pd.errors.ParserError as e:
    print(f"Error reading CSV: {e}")
# Out:
# Dataset loaded successfully!

# %%
news_dataset.dropna(inplace=True)
news_dataset.reset_index(inplace=True)

# %%
news_dataset.head()
# Out:
#                                              level_0  \
# 0                                                  0
# 1  I can certainly tell you what it means histori...
# 2                                        And besides
# 3                                  The United States
# 4        But four nuclear weapons states broke ranks
#
#                                              level_1  \
# 0  House Dem Aide: We Didnât Even See Comeyâs...
# 1                          âtruthâ must match up
# 2                                              truly
# 3   which led the opposition had hoped to limit t...
# 4                                         with China
#
#                                               id  \
# 0                                  Darrell Lucus
# 1                                       fit with
# 2                            during the 1960âs
# 3   but failed badly. The final vote was 123 For
# 4                  India and Pakistan abstaining
#
# ...

# %%
X = news_dataset['title']
y = news_dataset['label']

# %%
news_dataset.head(100)
# Out:
#                                               level_0  \
# 0                                                   0
# 1   I can certainly tell you what it means histori...
# 2                                         And besides
# 3                                   The United States
# 4         But four nuclear weapons states broke ranks
# ..                                                ...
# 95                                             Indeed
# 96  Acceptance of âa Jewish state on only part o...
# 97                                            In fact
# 98                                âBut generallyâ
# 99      Nor were the Arabsâ fears unfounded; indeed
#
#                                               level_1  \
# 0   House Dem Aide: We Didnât Even See Comeyâs...
# 1                           âtruthâ must match up
# 2                                               truly
# 3    which led the opposition had hoped to limit t...
# ...

# %%
ps = PorterStemmer()
corpus = []

for i in range(len(X)):
    text = X[i]
    text = re.sub('[^a-zA-Z]',' ',text)
    text = text.lower()
    text = text.split()
    text = [ps.stem(t) for t in text if t not in stopwords.words('english')]
    corpus.append(' '.join(text))

# %%
print(len(corpus))
print(corpus)
# Out:
# 4583
# ...
